# %% [markdown]
# # `Import required libraries`

# %%
## Load the required Libraries

import warnings
warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.asst_node_Interactivity = 'all'

# %% [markdown]
# ## `Import tips dataset`

# %%
df = pd.read_csv('data/tips.csv')

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# #### 1. Write a Python program to display a bar chart of the total bill of Gender and write the intuition about the plot.

# %%
### code here
ax = sns.barplot(y='total_bill',x='sex',data=df,ci=None)
ax.bar_label(ax.containers[0], fontsize=10)
# Out:
# [Text(0, 0, '18.0569'), Text(0, 0, '20.7441')]

# %% [markdown]
# #### Intuition :
#
# * In this above Bar chart, we can see the relation between 'total_bill' and 'sex' from tips dataset.
# * We take 'sex' on x-axis and 'total_bill' on y-axis in plot.
# * We have one bar for 'Female' data and another bar for 'Male' data of 'sex' column in above plot.
# * And add the aggregate counts on top of each bar in above chart.

# %% [markdown]
# ##### 2. Write a Python program to display a box plot of the total bill of day and hue = "smoker" and write the intuition about the plot.

# %%
#### code here
sns.boxplot(y='total_bill',x='day',hue='smoker',data=df)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %% [markdown]
# #### Intuition :
#
# * In this above Box plot, we can see the relation between 'total_bill' and 'day' with hue='smoker' from tips dataset.
# * We take 'day' on x-axis and 'total_bill' on y-axis in plot.
# * We have 2 different whiskers to show that, one is for 'smoker' and another one is for 'non-smoker' in above box plot.
# * The dots above and below the whisker are outliers in dataset.

# %% [markdown]
# #### 3. Write a Python program to display a violin plot of the total bill of Day and hue = "sex" and write the intuition about the plot.

# %%
### code here
sns.violinplot(y='total_bill',x='day',hue='sex',data=df)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %% [markdown]
# #### Intuition :
#
# * In this above Violin plot, we can see the relation between 'total_bill' and 'day' with hue='sex' from tips dataset.
# * We take 'day' on x-axis and 'total_bill' on y-axis in plot.
# * We have two different violins to show that, one violin is for 'Female' and another violin is for 'Male' in above Violin plot.

# %% [markdown]
# #### 4. Write a Python program to display a strip plot of the total bill of Day and hue = "sex" and write the intuition about the plot.

# %%
### code here 
sns.stripplot(data=df, y="total_bill", x="day", hue="sex")
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %% [markdown]
# #### Intuition :
#
# * In this above Strip plot, we can see the relation between 'total_bill' and 'day' with hue='sex' from tips dataset.
# * We take 'day' on x-axis and 'total_bill' on y-axis in plot.
# * We can see the two different colors to Markers, because it shows the difference for 'Male' & 'Female' in above Strip plot.

# %% [markdown]
# #### 5. Write a Python program to display heat map of dataframe and write the intuition about the plot.

# %%
### code here
sns.heatmap(data=df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Intuition :
#
# * In this above Heatmap, we can see the relation b\w all numerical columns i.e.,'total_bill', 'tip', 'size' from tips dataset.
# * We take 'total_bill', 'tip', 'size' on index as well as columns in plot.
# * We use annot to represent the cell values with text.

# %% [markdown]
# #### 6. Write a Python program to display scatter plot of total bill of tip and write the intuition about the plot.

# %%
### code here
sns.scatterplot(data=df, x="total_bill", y="tip")
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# #### Intuition :
#
# * In this above Scatter plot, we can see the relation between 'total_bill' and 'tip' from tips dataset.
# * We take 'total_bill' on x-axis and 'tip' on y-axis in plot.
# * According to above Scatter plot, most of the data(markers) are plotted in between 0 to 40 of 'total_bill' & 0 to 6 of 'tip'.

# %% [markdown]
# #### 7. Write a Python program to display density plot of all numerical columns from the dataframe and write the intution about plot.

# %%
### code here
sns.kdeplot(data=df)
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# #### Intuition :
#
# * We are using Density plot as known as a kernel density estimate (KDE) plot.
# * In above Density plot, we can see the relation b\w all numerical columns i.e.,'total_bill','tip','size' from tips dataset.
# * we take 'sex' on x-axis and 'total_bill' on y-axis in plot.
# * Plot distributions for each column of a wide-form dataset.

# %% [markdown]
# #### 8. Write a Python program to calculate average total bills by days and display top 4 days by plot.

# %%
### code here
ax = df.groupby(by=['day'])['total_bill'].mean().sort_values().plot(kind='bar')
ax.bar_label(ax.containers[0], fontsize=10)
# Out:
# [Text(0, 0, '17.1516'),
#  Text(0, 0, '17.6827'),
#  Text(0, 0, '20.4414'),
#  Text(0, 0, '21.41')]

# %% [markdown]
# ### Bonus Question

# %% [markdown]
# ##### 1. What is Histogram chart ?

# %% [markdown]
# # `Ans` :

# %% [markdown]
# ### `Histogram chart` :
#
# * A histogram is a classic visualization tool that represents\
#   the distribution of one or more variables by counting the number of observations that fall within discrete bins.
#
# * This function can normalize the statistic computed within each bin to estimate frequency, density or probability mass,\
#   and it can add a smooth curve obtained using a kernel density estimate, similar to kdeplot().
#
# <br>
#
# #### `Syntax` :
#      seaborn.histplot(data=None, *, x=None, y=None, hue=None, weights=None, stat='count',\
#                       bins='auto', binwidth=None, binrange=None, discrete=None, cumulative=False,\
#                       common_bins=True, common_norm=True, multiple='layer', element='bars',\
#                       fill=True, shrink=1, kde=False, kde_kws=None, line_kws=None, thresh=0,\
#                       pthresh=None, pmax=None, cbar=False, cbar_ax=None, cbar_kws=None, palette=None,\
#                       hue_order=None, hue_norm=None, color=None, log_scale=None, legend=True, ax=None, **kwargs)

# %% [markdown]
# #### 2. What is box plot ?

# %% [markdown]
# # `Ans` :

# %% [markdown]
# ### `Box plot` :
#
# * A box plot (or box-and-whisker plot) shows the distribution of quantitative data in a way that\
#   facilitates comparisons between variables or across levels of a categorical variable.
# * The box shows the quartiles of the dataset while the whiskers extend to show the rest of the distribution,\
#   except for points that are determined to be “outliers” using a method that is a function of the inter-quartile range.
#
# <br>
#
# #### `Syntax` :
#       seaborn.boxplot(data=None, *, x=None, y=None, hue=None, order=None,\
#                       hue_order=None, orient=None, color=None, palette=None, saturation=0.75,\
#                       width=0.8, dodge=True, fliersize=5, linewidth=None, whis=1.5, ax=None, **kwargs)

# %% [markdown]
# #### 3. What are the plots we can use for univeriate analysis.

# %% [markdown]
# # `Ans` :

# %% [markdown]
# #### `The plots we can use for univeriate analysis` :
#
# * Univariate Analysis is a type of data visualization where we visualize only a single variable at a time. Univariate Analysis   helps us to analyze the distribution of the variable present in the data so that we can perform further analysis. You can       find the link to the dataset here.
#
# * Simplest type of visualization: single-variable or "univariate" visualizations. This includes basic tools like bar plots       and line charts etc...
#
# * Univariate Analysis for Continuous Variables and Categorical Variables.
#
# <br>
#
# ##### They are :
#
#       1) Bar plot
#       2) Line plot
#       3) Joint plot
#       4) Histogram
#       5) Box plot
#       6) Violin plot
#       7) Scatter plot
#       8) Strip plot
#       9) Reg plot
#       10) Pie plot
#       11) Area chart

# %% [markdown]
# #### 4. What are the plots we can use for bivariate analysis.

# %% [markdown]
# # `Ans` :

# %% [markdown]
# #### `The plots we can use for biveriate analysis` :
#
# * Bivariate analysis is slightly more analytical than Univariate analysis. Bivariate analysis is the simultaneous analysis of two variables. It explores the concept of the relationship between two variable whether there exists an association and the strength of this association or whether there are differences between two variables and the significance of these differences.
#
# * Simplest type of visualization: "bivariate" visualizations. This includes basic tools like Scatter plots and bivariate         line charts etc...
#
# * Bivariate Analysis for Continuous Variable vs Continuous Variable, Categorical Variable vs Categorical Variable.
#
# <br>
#
# ##### They are :
#
#       1) Scatter plot
#       2) Stacked bar plot
#       3) Stacked area plot
#       4) Line plot
#       5) Heatmaps
#       6) Box plot
#       7) Violin plot
#       8) Swarm plot
#       9) Count plot
#       10) Bar plot
#       11) Crosstab

# %% [markdown]
# ##### 5. What are plot we can use for multivariate analysis.

# %% [markdown]
# # `Ans` :

# %% [markdown]
# #### `The plots we can use for multiiveriate analysis` :
#
# * Multivariate analysis is a more complex form of a statistical analysis technique and is used when there are more than two       variables in the data set.
#
# * Multivariate analysis involves analyzing the relationships between multiple variables (i.e. multivariate data) and             understanding how they influence each other. A Multivariate plotting method that works by "gridding out" the data.
#
# * Multivariate Analysis for Numerical-Numerical-Categorical Variables.
#
# <br>
#
# ##### They are :
#
#       1) Scatter Plot
#       2) Grouped Box Plot
#       3) Heatmap
#       4) Line charts
#       5) Pair plot
#       6) Histogram
#       7) Bar plot
