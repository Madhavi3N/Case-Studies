# %% [markdown]
# Dataset link --
# https://drive.google.com/drive/folders/1hVMm7tSn2yOzloWwJ-4yNeViMZHIRli8?usp=drive_link

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_csv(r"data\AMZNtrain.csv")

# %%
dataset
# Out:
#             Date         Open         High          Low        Close  \
# 0     2014-01-02   398.799988   399.359985   394.019989   397.970001
# 1     2014-01-03   398.290009   402.709991   396.220001   396.440002
# 2     2014-01-06   395.850006   397.000000   388.420013   393.630005
# 3     2014-01-07   395.040009   398.470001   394.290009   398.029999
# 4     2014-01-08   398.470001   403.000000   396.040009   401.920013
# ...          ...          ...          ...          ...          ...
# 1253  2018-12-24  1346.000000  1396.030029  1307.000000  1343.959961
# 1254  2018-12-26  1368.890015  1473.160034  1363.010010  1470.900024
# 1255  2018-12-27  1454.199951  1469.000000  1390.310059  1461.640015
# 1256  2018-12-28  1473.349976  1513.469971  1449.000000  1478.020020
# 1257  2018-12-31  1510.800049  1520.760010  1487.000000  1501.969971
#
#         Adj Close    Volume
# 0      397.970001   2137800
# 1      396.440002   2210200
# 2      393.630005   3170600
# ...

# %%
dataset.dtypes
# Out:
# Date          object
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume         int64
# dtype: object

# %%
dataset["Date"] = pd.to_datetime(dataset["Date"])

# %%
dataset.dtypes
# Out:
# Date         datetime64[ns]
# Open                float64
# High                float64
# Low                 float64
# Close               float64
# Adj Close           float64
# Volume                int64
# dtype: object

# %%
dataset
# Out:
#            Date         Open         High          Low        Close  \
# 0    2014-01-02   398.799988   399.359985   394.019989   397.970001
# 1    2014-01-03   398.290009   402.709991   396.220001   396.440002
# 2    2014-01-06   395.850006   397.000000   388.420013   393.630005
# 3    2014-01-07   395.040009   398.470001   394.290009   398.029999
# 4    2014-01-08   398.470001   403.000000   396.040009   401.920013
# ...         ...          ...          ...          ...          ...
# 1253 2018-12-24  1346.000000  1396.030029  1307.000000  1343.959961
# 1254 2018-12-26  1368.890015  1473.160034  1363.010010  1470.900024
# 1255 2018-12-27  1454.199951  1469.000000  1390.310059  1461.640015
# 1256 2018-12-28  1473.349976  1513.469971  1449.000000  1478.020020
# 1257 2018-12-31  1510.800049  1520.760010  1487.000000  1501.969971
#
#         Adj Close    Volume
# 0      397.970001   2137800
# 1      396.440002   2210200
# 2      393.630005   3170600
# 3      398.029999   1916000
# ...

# %%
dataset = dataset[["Date", "Open"]]

# %%
dataset
# Out:
#            Date         Open
# 0    2014-01-02   398.799988
# 1    2014-01-03   398.290009
# 2    2014-01-06   395.850006
# 3    2014-01-07   395.040009
# 4    2014-01-08   398.470001
# ...         ...          ...
# 1253 2018-12-24  1346.000000
# 1254 2018-12-26  1368.890015
# 1255 2018-12-27  1454.199951
# 1256 2018-12-28  1473.349976
# 1257 2018-12-31  1510.800049
#
# [1258 rows x 2 columns]

# %%
dataset.set_index("Date", inplace = True)

# %%
dataset
# Out:
#                    Open
# Date
# 2014-01-02   398.799988
# 2014-01-03   398.290009
# 2014-01-06   395.850006
# 2014-01-07   395.040009
# 2014-01-08   398.470001
# ...                 ...
# 2018-12-24  1346.000000
# 2018-12-26  1368.890015
# 2018-12-27  1454.199951
# 2018-12-28  1473.349976
# 2018-12-31  1510.800049
#
# [1258 rows x 1 columns]

# %%
#sort_index -- Sort the data by Date -- date -- index
dataset.sort_index(inplace = True)

# %%
dataset
# Out:
#                    Open
# Date
# 2014-01-02   398.799988
# 2014-01-03   398.290009
# 2014-01-06   395.850006
# 2014-01-07   395.040009
# 2014-01-08   398.470001
# ...                 ...
# 2018-12-24  1346.000000
# 2018-12-26  1368.890015
# 2018-12-27  1454.199951
# 2018-12-28  1473.349976
# 2018-12-31  1510.800049
#
# [1258 rows x 1 columns]

# %%
dataset.isnull().any()
# Out:
# Open    False
# dtype: bool

# %%
#to check for gaps
dataset.head()
# Out:
#                   Open
# Date
# 2014-01-02  398.799988
# 2014-01-03  398.290009
# 2014-01-06  395.850006
# 2014-01-07  395.040009
# 2014-01-08  398.470001

# %%
dataset.index[2]
# Out:
# Timestamp('2014-01-06 00:00:00')

# %%
diff = dataset.index[2] - dataset.index[1]

# %%
diff.days
# Out:
# 3

# %%
for idx in range(1,len(dataset)):
    diff = dataset.index[idx] - dataset.index[idx-1]
    if diff.days > 4:
        print(dataset.index[idx], diff.days)

# %%
dataset
# Out:
#                    Open
# Date
# 2014-01-02   398.799988
# 2014-01-03   398.290009
# 2014-01-06   395.850006
# 2014-01-07   395.040009
# 2014-01-08   398.470001
# ...                 ...
# 2018-12-24  1346.000000
# 2018-12-26  1368.890015
# 2018-12-27  1454.199951
# 2018-12-28  1473.349976
# 2018-12-31  1510.800049
#
# [1258 rows x 1 columns]

# %%
plt.figure(figsize = (15,5))#width, height
plt.plot(dataset)
plt.xlabel("Date")
plt.ylabel("Open Price")
plt.show()

# %% [markdown]
# ### Train and test split

# %%
round(len(dataset) * 0.8)
# Out:
# 1006

# %%
train_dataset = dataset.iloc[0:round(len(dataset) * 0.8)]

# %%
train_dataset
# Out:
#                    Open
# Date
# 2014-01-02   398.799988
# 2014-01-03   398.290009
# 2014-01-06   395.850006
# 2014-01-07   395.040009
# 2014-01-08   398.470001
# ...                 ...
# 2017-12-21  1175.900024
# 2017-12-22  1172.079956
# 2017-12-26  1168.359985
# 2017-12-27  1179.910034
# 2017-12-28  1189.000000
#
# [1006 rows x 1 columns]

# %%
test_dataset = dataset.iloc[round(len(dataset) * 0.8):]

# %%
test_dataset
# Out:
#                    Open
# Date
# 2017-12-29  1182.349976
# 2018-01-02  1172.000000
# 2018-01-03  1188.300049
# 2018-01-04  1205.000000
# 2018-01-05  1217.510010
# ...                 ...
# 2018-12-24  1346.000000
# 2018-12-26  1368.890015
# 2018-12-27  1454.199951
# 2018-12-28  1473.349976
# 2018-12-31  1510.800049
#
# [252 rows x 1 columns]

# %% [markdown]
# ### Min Max Scaler

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
sc = MinMaxScaler()

# %%
train_dataset = sc.fit_transform(train_dataset)

# %%
train_dataset
# Out:
# array([[0.12428297],
#        [0.12372894],
#        [0.12107814],
#        ...,
#        [0.96032503],
#        [0.97287288],
#        [0.98274813]])

# %%
test_dataset = sc.transform(test_dataset)

# %%
train_dataset
# Out:
# array([[0.12428297],
#        [0.12372894],
#        [0.12107814],
#        ...,
#        [0.96032503],
#        [0.97287288],
#        [0.98274813]])

# %% [markdown]
# ### Prepare the Data

# %%
train_dataset.shape
# Out:
# (1006, 1)

# %%
X_train = []
y_train = []

# %%
for i in range(60,len(train_dataset)):
    X_train.append(train_dataset[i-60:i,:])
    y_train.append(train_dataset[i,:])

# %%
X_train = np.array(X_train)
y_train = np.array(y_train)

# %%
X_train
# Out:
# array([[[0.12428297],
#         [0.12372894],
#         [0.12107814],
#         ...,
#         [0.07901313],
#         [0.06382539],
#         [0.06045758]],
#
#        [[0.12372894],
#         [0.12107814],
#         [0.12019817],
#         ...,
#         [0.06382539],
#         [0.06045758],
#         [0.0630106 ]],
#
#        [[0.12107814],
#         [0.12019817],
#         [0.12392448],
#         ...,
#         [0.06045758],
#         [0.0630106 ],
#         [0.05832826]],
#
#        ...,
#
#        [[0.73408437],
#         [0.73831044],
#         [0.73179211],
#         ...,
#         [0.98437771],
#         [0.96851645],
#         [0.96436636]],
#
#        [[0.73831044],
#         [0.73179211],
#         [0.72767471],
#         ...,
#         [0.96851645],
#         [0.96436636],
#         [0.96032503]],
#
#        [[0.73179211],
#         [0.72767471],
#         [0.74482878],
#         ...,
#         [0.96436636],
#         [0.96032503],
#         [0.97287288]]])

# %%
X_train.shape
# Out:
# (946, 60, 1)

# %%
y_train.shape
# Out:
# (946, 1)

# %% [markdown]
# ### Build the RNN Architecture

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense

# %%
from tensorflow.keras.layers import Input

# %%
from tensorflow.keras.layers import SimpleRNN

# %% [markdown]
# ### Init the model

# %%
rnn_model = Sequential()

# %% [markdown]
# ### Add input layer

# %%
inp_layer = Input(shape = (60,1))

# %%
rnn_model.add(inp_layer)

# %% [markdown]
# ### Add simple RNN Layer

# %%
#recurrent_initializer -- recurrent weights
#return_sequences -- True -- Sequence of output
                     #False -- Vectoe
#units -- no neurns
rnn_layer_1 = SimpleRNN(kernel_initializer = "random_uniform", recurrent_initializer = "random_uniform", 
                        return_sequences = True, activation = "relu", units = 100 )

# %%
rnn_model.add(rnn_layer_1)

# %%
rnn_layer_2 = SimpleRNN(kernel_initializer = "random_uniform", recurrent_initializer = "random_uniform", 
                        return_sequences = False, activation = "relu", units = 150 )

# %%
rnn_model.add(rnn_layer_2)

# %% [markdown]
# #### Add Output layer

# %%
output_layer = Dense(kernel_initializer = "random_uniform", activation = "linear", units = 1)

# %%
rnn_model.add(output_layer)

# %%
rnn_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  simple_rnn (SimpleRNN)      (None, 60, 100)           10200
#
#  simple_rnn_1 (SimpleRNN)    (None, 150)               37650
#
#  dense (Dense)               (None, 1)                 151
#
# ...
# Total params: 48001 (187.50 KB)
# Trainable params: 48001 (187.50 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
from tensorflow.keras.utils import plot_model

# %%
plot_model(rnn_model, show_shapes= True, )
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.

# %%
rnn_model.compile(loss = "mse", optimizer = "adam", metrics = "mse")

# %% [markdown]
# ###### Train the model

# %%
rnn_model.fit(X_train, y_train, batch_size = 32, epochs = 15)
# Out:
# Epoch 1/15
# 30/30 [==============================] - 4s 46ms/step - loss: 0.1076 - mse: 0.1076
# Epoch 2/15
# 30/30 [==============================] - 1s 43ms/step - loss: 0.0084 - mse: 0.0084
# Epoch 3/15
# 30/30 [==============================] - 1s 45ms/step - loss: 7.1734e-04 - mse: 7.1734e-04
# Epoch 4/15
# 30/30 [==============================] - 1s 44ms/step - loss: 4.1795e-04 - mse: 4.1795e-04
# Epoch 5/15
# 30/30 [==============================] - 1s 42ms/step - loss: 4.1660e-04 - mse: 4.1660e-04
# Epoch 6/15
# 30/30 [==============================] - 1s 44ms/step - loss: 3.7847e-04 - mse: 3.7847e-04
# Epoch 7/15
# 30/30 [==============================] - 1s 44ms/step - loss: 3.8561e-04 - mse: 3.8561e-04
# Epoch 8/15
# 30/30 [==============================] - 2s 62ms/step - loss: 3.4855e-04 - mse: 3.4855e-04
# Epoch 9/15
# 30/30 [==============================] - 1s 48ms/step - loss: 3.8818e-04 - mse: 3.8818e-04
# Epoch 10/15
# ...

# %% [markdown]
# ### Predictions

# %%
test_dataset
# Out:
# array([[0.97552361],
#        [0.9642795 ],
#        [0.98198771],
#        [1.00013036],
#        [1.01372111],
#        [1.03380844],
#        [1.05651401],
#        [1.04374893],
#        [1.05959932],
#        [1.07442857],
#        [1.12832435],
#        [1.11663478],
#        [1.09676467],
#        [1.11637406],
#        [1.10026295],
#        [1.14471793],
#        [1.184621  ],
#        [1.17721188],
#        [1.20329611],
#        [1.22194947],
#        [1.21542026],
#        [1.2677082 ],
#        [1.26086389],
#        [1.29605207],
#        [1.21482269],
#        [1.17010685],
#        [1.26520945],
#        [1.24422046],
#        [1.18317615],
#        [1.17359425],
#        [1.19669091],
#        [1.21876629],
#        [1.28464498],
#        [1.27430252],
#        [1.2624826 ],
#        [1.30431948],
#        [1.31557446],
#        [1.31555271],
#        [1.33061005],
#        [1.34723187],
#        [1.3418108 ],
#        [1.3353902 ],
#        [1.28704585],
# ...

# %%
len(test_dataset)
# Out:
# 252

# %%
train_dataset[-60:]
# Out:
# array([[0.72767471],
#        [0.74482878],
#        [0.75095604],
#        [0.77007647],
#        [0.77380278],
#        [0.76793631],
#        [0.77395489],
#        [0.7850252 ],
#        [0.7865896 ],
#        [0.78349342],
#        [0.78749133],
#        [0.76655658],
#        [0.77039156],
#        [0.76300406],
#        [0.74374239],
#        [0.7535199 ],
#        [0.75605121],
#        [0.84058319],
#        [0.88063837],
#        [0.89583695],
#        [0.89192597],
#        [0.88368031],
#        [0.87644492],
#        [0.89599993],
#        [0.91293671],
#        [0.9108508 ],
#        [0.91426208],
#        [0.91441419],
#        [0.91104641],
#        [0.91877062],
#        [0.91540284],
#        [0.91882499],
#        [0.92764647],
#        [0.91840129],
#        [0.92175819],
#        [0.93060142],
#        [0.95200324],
#        [0.99758825],
#        [1.        ],
#        [0.98904924],
#        [0.95895617],
#        [0.96433387],
#        [0.9662893 ],
# ...

# %%
test_dataset
# Out:
# array([[0.97552361],
#        [0.9642795 ],
#        [0.98198771],
#        [1.00013036],
#        [1.01372111],
#        [1.03380844],
#        [1.05651401],
#        [1.04374893],
#        [1.05959932],
#        [1.07442857],
#        [1.12832435],
#        [1.11663478],
#        [1.09676467],
#        [1.11637406],
#        [1.10026295],
#        [1.14471793],
#        [1.184621  ],
#        [1.17721188],
#        [1.20329611],
#        [1.22194947],
#        [1.21542026],
#        [1.2677082 ],
#        [1.26086389],
#        [1.29605207],
#        [1.21482269],
#        [1.17010685],
#        [1.26520945],
#        [1.24422046],
#        [1.18317615],
#        [1.17359425],
#        [1.19669091],
#        [1.21876629],
#        [1.28464498],
#        [1.27430252],
#        [1.2624826 ],
#        [1.30431948],
#        [1.31557446],
#        [1.31555271],
#        [1.33061005],
#        [1.34723187],
#        [1.3418108 ],
#        [1.3353902 ],
#        [1.28704585],
# ...

# %%
test_data = np.concatenate([train_dataset[-60:], test_dataset], axis = 0)

# %%
test_data
# Out:
# array([[0.72767471],
#        [0.74482878],
#        [0.75095604],
#        [0.77007647],
#        [0.77380278],
#        [0.76793631],
#        [0.77395489],
#        [0.7850252 ],
#        [0.7865896 ],
#        [0.78349342],
#        [0.78749133],
#        [0.76655658],
#        [0.77039156],
#        [0.76300406],
#        [0.74374239],
#        [0.7535199 ],
#        [0.75605121],
#        [0.84058319],
#        [0.88063837],
#        [0.89583695],
#        [0.89192597],
#        [0.88368031],
#        [0.87644492],
#        [0.89599993],
#        [0.91293671],
#        [0.9108508 ],
#        [0.91426208],
#        [0.91441419],
#        [0.91104641],
#        [0.91877062],
#        [0.91540284],
#        [0.91882499],
#        [0.92764647],
#        [0.91840129],
#        [0.92175819],
#        [0.93060142],
#        [0.95200324],
#        [0.99758825],
#        [1.        ],
#        [0.98904924],
#        [0.95895617],
#        [0.96433387],
#        [0.9662893 ],
# ...

# %%
len(test_data)
# Out:
# 312

# %%
X_test = []
y_test = []

# %%
for i in range(60,len(test_data)):
    X_test.append(test_data[i-60:i,:])
    y_test.append(test_data[i,:])

# %%
X_test = np.array(X_test)
y_test = np.array(y_test)

# %%
X_test
# Out:
# array([[[0.72767471],
#         [0.74482878],
#         [0.75095604],
#         ...,
#         [0.96032503],
#         [0.97287288],
#         [0.98274813]],
#
#        [[0.74482878],
#         [0.75095604],
#         [0.77007647],
#         ...,
#         [0.97287288],
#         [0.98274813],
#         [0.97552361]],
#
#        [[0.75095604],
#         [0.77007647],
#         [0.77380278],
#         ...,
#         [0.98274813],
#         [0.97552361],
#         [0.9642795 ]],
#
#        ...,
#
#        [[1.88769987],
#         [1.8637993 ],
#         [1.84392919],
#         ...,
#         [1.28258081],
#         [1.15331131],
#         [1.17817879]],
#
#        [[1.8637993 ],
#         [1.84392919],
#         [1.8084043 ],
#         ...,
#         [1.15331131],
#         [1.17817879],
#         [1.27085862]],
#
#        [[1.84392919],
#         [1.8084043 ],
#         [1.77471534],
#         ...,
#         [1.17817879],
#         [1.27085862],
#         [1.29166301]]])

# %%
X_test.shape
# Out:
# (252, 60, 1)

# %%
y_test.shape
# Out:
# (252, 1)

# %%
y_pred = rnn_model.predict(X_test)
# Out:
# 8/8 [==============================] - 0s 14ms/step

# %%
y_pred
# Out:
# array([[0.98984474],
#        [0.99131846],
#        [0.9904566 ],
#        [0.9916265 ],
#        [0.9964207 ],
#        [1.0040083 ],
#        [1.0145913 ],
#        [1.0282098 ],
#        [1.0387603 ],
#        [1.0487078 ],
#        [1.0592575 ],
#        [1.0769093 ],
#        [1.0928037 ],
#        [1.101965  ],
#        [1.1099888 ],
#        [1.1139425 ],
#        [1.1226231 ],
#        [1.1383551 ],
#        [1.1531439 ],
#        [1.1689998 ],
#        [1.1857318 ],
#        [1.1990442 ],
#        [1.2170081 ],
#        [1.2330614 ],
#        [1.2511033 ],
#        [1.2542598 ],
#        [1.2434958 ],
#        [1.2442609 ],
#        [1.2469484 ],
#        [1.2398795 ],
#        [1.2282714 ],
#        [1.2206835 ],
#        [1.219675  ],
#        [1.2318686 ],
#        [1.2457446 ],
#        [1.2557062 ],
#        [1.2689791 ],
#        [1.2834295 ],
#        [1.2958949 ],
#        [1.3078448 ],
#        [1.3203534 ],
#        [1.330227  ],
#        [1.3363527 ],
# ...

# %%
y_test
# Out:
# array([[0.97552361],
#        [0.9642795 ],
#        [0.98198771],
#        [1.00013036],
#        [1.01372111],
#        [1.03380844],
#        [1.05651401],
#        [1.04374893],
#        [1.05959932],
#        [1.07442857],
#        [1.12832435],
#        [1.11663478],
#        [1.09676467],
#        [1.11637406],
#        [1.10026295],
#        [1.14471793],
#        [1.184621  ],
#        [1.17721188],
#        [1.20329611],
#        [1.22194947],
#        [1.21542026],
#        [1.2677082 ],
#        [1.26086389],
#        [1.29605207],
#        [1.21482269],
#        [1.17010685],
#        [1.26520945],
#        [1.24422046],
#        [1.18317615],
#        [1.17359425],
#        [1.19669091],
#        [1.21876629],
#        [1.28464498],
#        [1.27430252],
#        [1.2624826 ],
#        [1.30431948],
#        [1.31557446],
#        [1.31555271],
#        [1.33061005],
#        [1.34723187],
#        [1.3418108 ],
#        [1.3353902 ],
#        [1.28704585],
# ...

# %%
y_test = sc.inverse_transform(y_test)

# %%
y_pred = sc.inverse_transform(y_pred)

# %%
y_test
# Out:
# array([[1182.349976],
#        [1172.      ],
#        [1188.300049],
#        [1205.      ],
#        [1217.51001 ],
#        [1236.      ],
#        [1256.900024],
#        [1245.150024],
#        [1259.73999 ],
#        [1273.390015],
#        [1323.      ],
#        [1312.23999 ],
#        [1293.949951],
#        [1312.      ],
#        [1297.170044],
#        [1338.089966],
#        [1374.819946],
#        [1368.      ],
#        [1392.01001 ],
#        [1409.180054],
#        [1403.170044],
#        [1451.300049],
#        [1445.      ],
#        [1477.390015],
#        [1402.619995],
#        [1361.459961],
#        [1449.      ],
#        [1429.680054],
#        [1373.48999 ],
#        [1364.670044],
#        [1385.930054],
#        [1406.25    ],
#        [1466.890015],
#        [1457.369995],
#        [1446.48999 ],
#        [1485.      ],
#        [1495.359985],
#        [1495.339966],
#        [1509.199951],
#        [1524.5     ],
#        [1519.51001 ],
# ...

# %%
y_pred
# Out:
# array([[1195.5322],
#        [1196.8889],
#        [1196.0955],
#        [1197.1724],
#        [1201.5853],
#        [1208.5696],
#        [1218.311 ],
#        [1230.8466],
#        [1240.5581],
#        [1249.7146],
#        [1259.4254],
#        [1275.6735],
#        [1290.304 ],
#        [1298.7367],
#        [1306.1226],
#        [1309.7618],
#        [1317.7522],
#        [1332.2332],
#        [1345.846 ],
#        [1360.4409],
#        [1375.8424],
#        [1388.0963],
#        [1404.6317],
#        [1419.4084],
#        [1436.0156],
#        [1438.9211],
#        [1429.0131],
#        [1429.7173],
#        [1432.191 ],
#        [1425.6843],
#        [1414.9993],
#        [1408.0148],
#        [1407.0864],
#        [1418.3104],
#        [1431.083 ],
#        [1440.2524],
#        [1452.4698],
#        [1465.7712],
#        [1477.2454],
#        [1488.245 ],
#        [1499.7589],
#        [1508.8474],
#        [1514.486 ],
#        [1510.8049],
#        [1507.9196],
# ...

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
mse = mean_squared_error(y_test, y_pred)

# %%
rmse = np.sqrt(mse)

# %%
rmse
# Out:
# 55.38013813377811

# %%
mean_absolute_error(y_test, y_pred)
# Out:
# 40.7623993345114

# %%
test_data_dates = dataset.iloc[1006:,].index

# %%
plt.figure(figsize = (15,5))
plt.plot(test_data_dates, y_test, label = "Actual Data")

plt.plot(test_data_dates, y_pred, label = "Predicted Data")

plt.legend()
plt.show()

# %% [markdown]
# ### Save the model

# %%
rnn_model.save("amazon_stock.h5")
# Out:
# C:\Users\7240\anaconda3\lib\site-packages\keras\src\engine\training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %% [markdown]
# #### save the scaler object

# %%
import joblib

# %%
joblib.dump(sc, "amazon_stock_sc0.pkl")
# Out:
# ['amazon_stock_sc0.pkl']
